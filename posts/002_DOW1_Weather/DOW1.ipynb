# %% [raw]
# ---
# title: "Dataset of the Week 1 - The Weather in Philadelphia"
# description: "Is it really always Sunny..."
# author: "Sose Hovannisian"
# date: "1/28/2026"
# categories:
#   - DOW
#   - Weather
# ---

# %% [markdown]
# ### My post

# %%
print('This is some code')
# Out:
# This is some code

# %% [markdown]
# ---
# The Next Section
# ---
# ---
# And another
# ---

# %%
27, 101, 310
# Out:
# (27, 101, 310)
