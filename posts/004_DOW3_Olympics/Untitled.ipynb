# %% [raw]
# ---
# title: "Dataset of the Week 3 - Winter Olympics"
# description: "National Pride during the Winter Olympics"
# author: "Sose Hovannisian"
# date: "2/19/2026"
# categories:
#   - DOW
#   - Winter Olympics
#   - Armenia
# ---

# %% [markdown]
# ### Armenia may not be the country you look out for during the Olympics, but it's always first in my mind!
#
# #### As a proud Armenian, I always look for my nation in global events like the Olympics, Eurovision, and the World Cup.
